# %%
import numpy as np
import pandas as pd
import time

import pymorphy3
import nltk
from nltk.tokenize import word_tokenize
#from nltk.corpus import stopwords
import string

#nltk.download('punkt')
#nltk.download('stopwords')

# %%
names = ['id',
         'headline',
         'description',
         'article_body',
         'date',
         'newspaper',
         'city',
         'md_index',
         'url']

data = pd.read_excel('SV-women-data.xlsx',
                     index_col = 0,
                     names = names)
data
# Out:
#           id                                           headline  \
# 0          1  «Женщины для утех» по-прежнему нужны: Япония и...
# 1          2   В Норвегии мигрантов научат не насиловать женщин
# 2          3  Полиция Кельна опровергла сообщения о нападени...
# 3          4  Меркель потребовала дать жесткий ответ на напа...
# 4          5  В центре Кельна около тысячи мигрантов устроил...
# ...      ...                                                ...
# 15337  15338  Стало известно о гибели в зоне СВО «тулунского...
# 15338  15339  Просто эпидемия: старшего брата Майкла Джексон...
# 15339  15340     Брата Майкла Джексона обвинили в изнасиловании
# 15340  15341  Более 600 деятелей культуры осудили обвиняемог...
# 15341  15342  Член жюри телешоу «Американский идол» обвинила...
#
#                                              description  \
# 0      Во время колонизации Кореи Японией в XX веке к...
# 1      Наплыв беженцев из Сирии и других стран Ближне...
# 2      Канцлер ФРГ Ангела Меркель назвала правонаруше...
# 3      \tКанцлер Германии Ангела Меркель потребовала ...
# 4      Полиция Германии расследует информацию о серий...
# ...                                                  ...
# 15337  Заключивший контракт с одной из частных военны...
# 15338  Основателя группы The Jackson 5, старшего брат...
# 15339  Брата американского поп-исполнителя Майкла Дже...
# 15340  Более 600 деятелей культуры осудили обвиняемог...
# 15341  Певица Пола Абдул, которая в течение восьми ле...
#
#                                             article_body       date  \
# 0      Во время колонизации Кореи Японией в XX веке к... 2016-01-03
# 1      \n                                            ... 2016-01-04
# 2      Об этом сообщил спикер правительства ФРГ Штефф... 2016-01-05
# 3      Сейчас+6˚CСейчас в Санкт-ПетербургеОблачно, Бе... 2016-01-05
# 4      По словам жертв, они попали в агрессивную толп... 2016-01-06
# ...                                                  ...        ...
# 15337  \n\n\n\n\nЗаключивший контракт с одной из част... 2023-12-28
# 15338  Основателя группы The Jackson 5, старшего брат... 2023-12-29
# 15339  \n                                            ... 2023-12-29
# 15340    30 декабря 2023, 11:49 — Общественная служба... 2023-12-30
# 15341  Певица Пола Абдул, которая в течение восьми ле... 2023-12-30
#
#                                         newspaper             city  md_index  \
# 0                                       ИА Regnum           Москва     2.312
# 1                                Известия (iz.ru)           Москва     1.113
# 2                       Российская газета (rg.ru)           Москва     1.266
# 3                          Фонтанка (fontanka.ru)  Санкт-Петербург     1.186
# 4                    Комсомольская правда (kp.ru)           Москва     0.960
# ...                                           ...              ...       ...
# 15337              Свободная пресса (svpressa.ru)           Москва     0.922
# 15338                                 Eadaily.com           Москва     1.469
# 15339                            Известия (iz.ru)           Москва     1.200
# 15340  Общественная служба новостей (osnmedia.ru)           Москва     0.959
# 15341                                   Газета.Ru           Москва     1.324
#
#                                                      url
# 0                     http://regnum.ru/news/2048238.html
# 1                         http://izvestia.ru/news/600956
# 2             http://www.rg.ru/2016/01/05/keln-site.html
# 3                 http://www.fontanka.ru/2016/01/05/077/
# 4                  http://www.kp.ru/daily/26476/3347751/
# ...                                                  ...
# 15337             https://svpressa.ru/war21/news/399920/
# 15338  https://eadaily.com/ru/news/2023/12/29/prosto-...
# 15339  https://iz.ru/1628155/2023-12-29/brata-maikla-...
# 15340  https://www.osnmedia.ru/kultura/bolee-600-deya...
# 15341  https://www.gazeta.ru/culture/news/2023/12/30/...
#
# [15342 rows x 9 columns]

# %%
data[['headline', 'description', 'article_body']] = data[['headline', 'description', 'article_body']].astype(str)
all_texts = data[['headline', 'description', 'article_body']].agg('-'.join, axis=1)
data.insert(4, 'all_text', all_texts, True)
data
# Out:
#           id                                           headline  \
# 0          1  «Женщины для утех» по-прежнему нужны: Япония и...
# 1          2   В Норвегии мигрантов научат не насиловать женщин
# 2          3  Полиция Кельна опровергла сообщения о нападени...
# 3          4  Меркель потребовала дать жесткий ответ на напа...
# 4          5  В центре Кельна около тысячи мигрантов устроил...
# ...      ...                                                ...
# 15337  15338  Стало известно о гибели в зоне СВО «тулунского...
# 15338  15339  Просто эпидемия: старшего брата Майкла Джексон...
# 15339  15340     Брата Майкла Джексона обвинили в изнасиловании
# 15340  15341  Более 600 деятелей культуры осудили обвиняемог...
# 15341  15342  Член жюри телешоу «Американский идол» обвинила...
#
#                                              description  \
# 0      Во время колонизации Кореи Японией в XX веке к...
# 1      Наплыв беженцев из Сирии и других стран Ближне...
# 2      Канцлер ФРГ Ангела Меркель назвала правонаруше...
# 3      \tКанцлер Германии Ангела Меркель потребовала ...
# 4      Полиция Германии расследует информацию о серий...
# ...                                                  ...
# 15337  Заключивший контракт с одной из частных военны...
# 15338  Основателя группы The Jackson 5, старшего брат...
# 15339  Брата американского поп-исполнителя Майкла Дже...
# 15340  Более 600 деятелей культуры осудили обвиняемог...
# 15341  Певица Пола Абдул, которая в течение восьми ле...
#
#                                             article_body  \
# 0      Во время колонизации Кореи Японией в XX веке к...
# 1      \n                                            ...
# 2      Об этом сообщил спикер правительства ФРГ Штефф...
# 3      Сейчас+6˚CСейчас в Санкт-ПетербургеОблачно, Бе...
# 4      По словам жертв, они попали в агрессивную толп...
# ...                                                  ...
# 15337  \n\n\n\n\nЗаключивший контракт с одной из част...
# 15338  Основателя группы The Jackson 5, старшего брат...
# 15339  \n                                            ...
# 15340    30 декабря 2023, 11:49 — Общественная служба...
# 15341  Певица Пола Абдул, которая в течение восьми ле...
#
#                                                 all_text       date  \
# 0      «Женщины для утех» по-прежнему нужны: Япония и... 2016-01-03
# 1      В Норвегии мигрантов научат не насиловать женщ... 2016-01-04
# 2      Полиция Кельна опровергла сообщения о нападени... 2016-01-05
# 3      Меркель потребовала дать жесткий ответ на напа... 2016-01-05
# 4      В центре Кельна около тысячи мигрантов устроил... 2016-01-06
# ...                                                  ...        ...
# 15337  Стало известно о гибели в зоне СВО «тулунского... 2023-12-28
# 15338  Просто эпидемия: старшего брата Майкла Джексон... 2023-12-29
# 15339  Брата Майкла Джексона обвинили в изнасиловании... 2023-12-29
# 15340  Более 600 деятелей культуры осудили обвиняемог... 2023-12-30
# 15341  Член жюри телешоу «Американский идол» обвинила... 2023-12-30
#
#                                         newspaper             city  md_index  \
# 0                                       ИА Regnum           Москва     2.312
# 1                                Известия (iz.ru)           Москва     1.113
# 2                       Российская газета (rg.ru)           Москва     1.266
# 3                          Фонтанка (fontanka.ru)  Санкт-Петербург     1.186
# 4                    Комсомольская правда (kp.ru)           Москва     0.960
# ...                                           ...              ...       ...
# 15337              Свободная пресса (svpressa.ru)           Москва     0.922
# 15338                                 Eadaily.com           Москва     1.469
# 15339                            Известия (iz.ru)           Москва     1.200
# 15340  Общественная служба новостей (osnmedia.ru)           Москва     0.959
# 15341                                   Газета.Ru           Москва     1.324
#
#                                                      url
# 0                     http://regnum.ru/news/2048238.html
# 1                         http://izvestia.ru/news/600956
# 2             http://www.rg.ru/2016/01/05/keln-site.html
# 3                 http://www.fontanka.ru/2016/01/05/077/
# 4                  http://www.kp.ru/daily/26476/3347751/
# ...                                                  ...
# 15337             https://svpressa.ru/war21/news/399920/
# 15338  https://eadaily.com/ru/news/2023/12/29/prosto-...
# 15339  https://iz.ru/1628155/2023-12-29/brata-maikla-...
# 15340  https://www.osnmedia.ru/kultura/bolee-600-deya...
# 15341  https://www.gazeta.ru/culture/news/2023/12/30/...
#
# [15342 rows x 10 columns]

# %%
def preprocess(text, punc, analyzer, stopw, alph):
    
    tokens = word_tokenize(text.replace('.', ' ').lower())
    tokens = [token for token in tokens if token not in punc]
    tokens = [analyzer.parse(token)[0].normal_form for token in tokens]
    tokens = [token for token in tokens if token not in stopw]
    tokens = [token for token in tokens if token.isalpha() == True]
    
    for token in tokens:
        for letter in token:
            if letter not in alph:
                tokens.remove(token)
                break
                
    return(tokens)

# %%
punctuation = open("punctuation.txt", "r", encoding = 'utf-8').read().strip().replace('\n', '') + string.punctuation 
morph = pymorphy3.MorphAnalyzer()
#stop_words = stopwords.words('russian') # слишком мало слов
stop_words = open("stopwords-ru.txt", "r", encoding = 'utf-8').read().strip().split('\n')
alphabet = string.ascii_uppercase + \
           string.ascii_lowercase + \
           'АБВГДЕЁЖЗИЙКЛМНОПРСТУФХЦЧШЩЪЫЬЭЮЯабвгдеёжзийклмнопрстуфхцчшщъыьэюя'

# %%
idx = np.random.randint(data.shape[0], size=1)[0]

preprocess(data.all_text[idx],
           punctuation,
           morph,
           stop_words, 
           alphabet)
# Out:
# ['глава',
#  'мид',
#  'фрг',
#  'анджелина',
#  'джоля',
#  'объединиться',
#  'борьба',
#  'сексуальный',
#  'насилие',
#  'кризисный',
#  'зона',
#  'стать',
#  'главный',
#  'председательство',
#  'германия',
#  'совет',
#  'безопасность',
#  'организация',
#  'объединить',
#  'апрель',
#  'иа',
#  'регнум',
#  'борьба',
#  'сексуальный',
#  'насилие',
#  'кризисный',
#  'зона',
#  'стать',
#  'главный',
#  'председательство',
#  'германия',
#  'совет',
#  'безопасность',
#  'организация',
#  'объединить',
#  'нация',
#  'оон',
#  'голливудский',
#  'актриса',
#  'анджелина',
#  'джоля',
#  'поддержать',
#  'усилие',
#  'берлин',
#  'опубликовать',
#  'совместный',
#  'гостевой',
#  'статья',
#  'министр',
#  'иностранный',
#  'дело',
#  'германия',
#  'хайко',
#  'маас',
#  'газета',
#  'the',
#  'washington',
#  'post',
#  'автор',
#  'статья',
#  'выступать',
#  'поддержка',
#  'жертва',
#  'насилие',
#  'улучшение',
#  'механизм',
#  'судебный',
#  'преследование',
#  'насильник',
#  'оба',
#  'приводить',
#  'пример',
#  'сложный',
#  'судьба',
#  'женщина',
#  'кризисный',
#  'зона',
#  'изнасилование',
#  'форма',
#  'сексуальный',
#  'насилие',
#  'использоваться',
#  'качество',
#  'военный',
#  'террористический',
#  'тактика',
#  'мир',
#  'говориться',
#  'статья',
#  'слишком',
#  'часто',
#  'преступление',
#  'сходить',
#  'рука',
#  'безнаказанность',
#  'иметь',
#  'разрушительный',
#  'последствие',
#  'германия',
#  'предлагать',
#  'принять',
#  'резолюция',
#  'оон',
#  'борьба',
#  'сексуальный',
#  'насилие',
#  'должный',
#  'включать',
#  'санкция',
#  'образ',
#  'поощрять',
#  'насилие',
#  'отношение',
#  'женщина',
#  'анджелина',
#  'джоля',
#  'год',
#  'заниматься',
#  'проблема',
#  'работать',
#  'вместе',
#  'бывший',
#  'министр',
#  'иностранный',
#  'дело',
#  'великобритания',
#  'уильям',
#  'хейг',
#  'год',
#  'назначить',
#  'специальный',
#  'посланник',
#  'управление',
#  'верховный',
#  'комиссар',
#  'оон',
#  'дело',
#  'беженец']

# %%
# %%time

texts_lem = []

for text in data.all_text:
    text_lem = preprocess(text, punctuation, morph, stop_words, alphabet)
    text_lem_str = " ".join(str(word) for word in text_lem)
    texts_lem.append(text_lem_str)
# Out:
# CPU times: total: 22min 57s
# Wall time: 23min 35s

# %%
data.insert(5, 'text_lem', texts_lem, True)
data
# Out:
#           id                                           headline  \
# 0          1  «Женщины для утех» по-прежнему нужны: Япония и...
# 1          2   В Норвегии мигрантов научат не насиловать женщин
# 2          3  Полиция Кельна опровергла сообщения о нападени...
# 3          4  Меркель потребовала дать жесткий ответ на напа...
# 4          5  В центре Кельна около тысячи мигрантов устроил...
# ...      ...                                                ...
# 15337  15338  Стало известно о гибели в зоне СВО «тулунского...
# 15338  15339  Просто эпидемия: старшего брата Майкла Джексон...
# 15339  15340     Брата Майкла Джексона обвинили в изнасиловании
# 15340  15341  Более 600 деятелей культуры осудили обвиняемог...
# 15341  15342  Член жюри телешоу «Американский идол» обвинила...
#
#                                              description  \
# 0      Во время колонизации Кореи Японией в XX веке к...
# 1      Наплыв беженцев из Сирии и других стран Ближне...
# 2      Канцлер ФРГ Ангела Меркель назвала правонаруше...
# 3      \tКанцлер Германии Ангела Меркель потребовала ...
# 4      Полиция Германии расследует информацию о серий...
# ...                                                  ...
# 15337  Заключивший контракт с одной из частных военны...
# 15338  Основателя группы The Jackson 5, старшего брат...
# 15339  Брата американского поп-исполнителя Майкла Дже...
# 15340  Более 600 деятелей культуры осудили обвиняемог...
# 15341  Певица Пола Абдул, которая в течение восьми ле...
#
#                                             article_body  \
# 0      Во время колонизации Кореи Японией в XX веке к...
# 1      \n                                            ...
# 2      Об этом сообщил спикер правительства ФРГ Штефф...
# 3      Сейчас+6˚CСейчас в Санкт-ПетербургеОблачно, Бе...
# 4      По словам жертв, они попали в агрессивную толп...
# ...                                                  ...
# 15337  \n\n\n\n\nЗаключивший контракт с одной из част...
# 15338  Основателя группы The Jackson 5, старшего брат...
# 15339  \n                                            ...
# 15340    30 декабря 2023, 11:49 — Общественная служба...
# 15341  Певица Пола Абдул, которая в течение восьми ле...
#
#                                                 all_text  \
# 0      «Женщины для утех» по-прежнему нужны: Япония и...
# 1      В Норвегии мигрантов научат не насиловать женщ...
# 2      Полиция Кельна опровергла сообщения о нападени...
# 3      Меркель потребовала дать жесткий ответ на напа...
# 4      В центре Кельна около тысячи мигрантов устроил...
# ...                                                  ...
# 15337  Стало известно о гибели в зоне СВО «тулунского...
# 15338  Просто эпидемия: старшего брата Майкла Джексон...
# 15339  Брата Майкла Джексона обвинили в изнасиловании...
# 15340  Более 600 деятелей культуры осудили обвиняемог...
# 15341  Член жюри телешоу «Американский идол» обвинила...
#
#                                                 text_lem       date  \
# 0      женщина утеха нужный япония китай борьба время... 2016-01-03
# 1      норвегия мигрант научить насиловать беженец си... 2016-01-04
# 2      полиция кёльн опровергнуть сообщение нападение... 2016-01-05
# 3      меркель потребовать дать жёсткий ответ нападен... 2016-01-05
# 4      центр кёльн тысяча мигрант устроить новогодний... 2016-01-06
# ...                                                  ...        ...
# 15337  стать известно гибель зона сво тулунский манья... 2023-12-28
# 15338  просто эпидемия старший брат майкл джексон обв... 2023-12-29
# 15339  брат майкл джексон обвинить американский майкл... 2023-12-29
# 15340  деятель культура осудить обвинять домогательст... 2023-12-30
# 15341  член жюри телешоу американский идол обвинить п... 2023-12-30
#
#                                         newspaper             city  md_index  \
# 0                                       ИА Regnum           Москва     2.312
# 1                                Известия (iz.ru)           Москва     1.113
# 2                       Российская газета (rg.ru)           Москва     1.266
# 3                          Фонтанка (fontanka.ru)  Санкт-Петербург     1.186
# 4                    Комсомольская правда (kp.ru)           Москва     0.960
# ...                                           ...              ...       ...
# 15337              Свободная пресса (svpressa.ru)           Москва     0.922
# 15338                                 Eadaily.com           Москва     1.469
# 15339                            Известия (iz.ru)           Москва     1.200
# 15340  Общественная служба новостей (osnmedia.ru)           Москва     0.959
# 15341                                   Газета.Ru           Москва     1.324
#
#                                                      url
# 0                     http://regnum.ru/news/2048238.html
# 1                         http://izvestia.ru/news/600956
# 2             http://www.rg.ru/2016/01/05/keln-site.html
# 3                 http://www.fontanka.ru/2016/01/05/077/
# 4                  http://www.kp.ru/daily/26476/3347751/
# ...                                                  ...
# 15337             https://svpressa.ru/war21/news/399920/
# 15338  https://eadaily.com/ru/news/2023/12/29/prosto-...
# 15339  https://iz.ru/1628155/2023-12-29/brata-maikla-...
# 15340  https://www.osnmedia.ru/kultura/bolee-600-deya...
# 15341  https://www.gazeta.ru/culture/news/2023/12/30/...
#
# [15342 rows x 11 columns]

# %%
data.to_excel('SV-women-data-lem.xlsx')
