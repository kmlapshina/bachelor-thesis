# %%
import pandas as pd
import numpy as np

import tomotopy as to
import tomotopy.coherence as coherence

import time

# %% [markdown]
# ## Loading data & creating a list of documents

# %%
# Loading data - dataset containing lemmatized texts
names = ['id',
         'headline',
         'description',
         'article_body',
         'all_text',
         'text_lem',
         'date',
         'newspaper',
         'city',
         'md_index',
         'url']

data = pd.read_excel('SV-women-data-lem.xlsx',
                     index_col = 0,
                     names = names)
data
# Out:
#           id                                           headline  \
# 0          1  «Женщины для утех» по-прежнему нужны: Япония и...
# 1          2   В Норвегии мигрантов научат не насиловать женщин
# 2          3  В Кельне задержали первого подозреваемого в на...
# 3          4  В Дании полицейские научат беженцев вежливому ...
# 4          5  А каждого Михеля демократично переименуют в Му...
# ...      ...                                                ...
# 15337  15338  «Фантазируя об изнасиловании, женщина чувствуе...
# 15338  15339  Обвиняемого в домогательствах екатеринбургског...
# 15339  15340  Анджелина Джоли и Гвинет Пэлтроу обвинили Вайн...
# 15340  15341  Адвокат Людмила Айвар рассказала, как российск...
# 15341  15342  Пэрис Хилтон рассказала о сексуальном насилии,...
#
#                                              description  \
# 0      Во время колонизации Кореи Японией в XX веке к...
# 1      Наплыв беженцев из Сирии и других стран Ближне...
# 2      \tПрокуратура Кельна сообщила о задержании пер...
# 3      В одной из пяти административных областей Дани...
# 4      Наш спецкор Дарья Асламова выясняет, в чем при...
# ...                                                  ...
# 15337  Почему во время месячных хочется больше секса,...
# 15338  Обвиняемого в домогательствах екатеринбургског...
# 15339  Звезды Голливуда Анджелина Джоли и Гвинет Пэлт...
# 15340  Адвокат Людмила Айвар рассказала, как российск...
# 15341  Американская актриса и модель Пэрис Хилтон рас...
#
#                                             article_body  \
# 0      Во время колонизации Кореи Японией в XX веке к...
# 1      \n                                            ...
# 2      Сейчас+6˚CСейчас в Санкт-ПетербургеОблачно, Бе...
# 3      В одной из пяти административных областей Дани...
# 4      В теплом кафе мой собеседник небрежно скидывае...
# ...                                                  ...
# 15337  \n— Получаю особенное удовольствие от секса во...
# 15338  6 октября – ИА SM.News. Обвиняемого в домогате...
# 15339  \n                                            ...
# 15340    7 марта 2023, 16:59 — Общественная служба но...
# 15341  Американская актриса и модель Пэрис Хилтон рас...
#
#                                                 all_text  \
# 0      «Женщины для утех» по-прежнему нужны: Япония и...
# 1      В Норвегии мигрантов научат не насиловать женщ...
# 2      В Кельне задержали первого подозреваемого в на...
# 3      В Дании полицейские научат беженцев вежливому ...
# 4      А каждого Михеля демократично переименуют в Му...
# ...                                                  ...
# 15337  «Фантазируя об изнасиловании, женщина чувствуе...
# 15338  Обвиняемого в домогательствах екатеринбургског...
# 15339  Анджелина Джоли и Гвинет Пэлтроу обвинили Вайн...
# 15340  Адвокат Людмила Айвар рассказала, как российск...
# 15341  Пэрис Хилтон рассказала о сексуальном насилии,...
#
#                                                 text_lem       date  \
# 0      женщина утеха нужный япония китай борьба время... 2016-01-03
# 1      норвегия мигрант научить насиловать беженец си... 2016-01-04
# 2      кёльн задержать первый подозревать нападение п... 2016-01-05
# 3      дания полицейский научить беженец вежливый обр... 2016-01-05
# 4      михель демократично переименовать спецкор дарь... 2016-01-06
# ...                                                  ...        ...
# 15337  фантазировать изнасилование женщина чувствоват... 2023-12-28
# 15338  обвинять домогательство екатеринбургский масса... 2023-12-29
# 15339  анджелина джоля гвинет пэлтроу обвинить вайншт... 2023-12-29
# 15340  адвокат людмила айвар рассказать российский же... 2023-12-30
# 15341  пэрис хилтон рассказать сексуальный насилие пе... 2023-12-30
#
#                                         newspaper             city  md_index  \
# 0                                       ИА Regnum           Москва     2.312
# 1                                Известия (iz.ru)           Москва     1.113
# 2                          Фонтанка (fontanka.ru)  Санкт-Петербург     1.186
# 3                       Российская газета (rg.ru)           Москва     1.266
# 4                    Комсомольская правда (kp.ru)           Москва     0.960
# ...                                           ...              ...       ...
# 15337                                   Газета.Ru           Москва     1.963
# 15338                                 Eadaily.com           Москва     1.469
# 15339                            Известия (iz.ru)           Москва     1.200
# 15340  Общественная служба новостей (osnmedia.ru)           Москва     0.959
# 15341                                   Газета.Ru           Москва     1.324
#
#                                                      url
# 0                     http://regnum.ru/news/2048238.html
# 1                         http://izvestia.ru/news/600956
# 2                 http://www.fontanka.ru/2016/01/05/077/
# 3             http://www.rg.ru/2016/01/05/keln-site.html
# 4                  http://www.kp.ru/daily/26476/3347751/
# ...                                                  ...
# 15337  https://www.gazeta.ru/culture/news/2023/12/28/...
# 15338  https://eadaily.com/ru/news/2023/12/29/prosto-...
# 15339  https://iz.ru/1628155/2023-12-29/brata-maikla-...
# 15340  https://www.osnmedia.ru/kultura/bolee-600-deya...
# 15341  https://www.gazeta.ru/culture/news/2023/12/30/...
#
# [15342 rows x 11 columns]

# %%
# Getting docs from data
docs = pd.DataFrame(data.text_lem)

# %%
# Extract unique words and calculate their number
uniq_words = list(filter(lambda x: x, set(docs.text_lem.str.cat(sep=' ').strip().split(' '))))
uniq_words_len = len(uniq_words)
print('The number of unique words is', uniq_words_len)
# Out:
# The number of unique words is 63240

# %%
# Transform documents into word lists
words_in_docs = list(map(lambda x: x.split(), docs.text_lem.dropna().values))

# %% [markdown]
# ## Main attributes

# %%
'''
# Topic distribution for each document (probabilities)
mdl.docs[0].get_topic_dist() 

# Word distribution for each topic (only probabilities)
mdl.get_topic_word_dist(topic_id = 0)

# Word distribution for each topic (words + probabilities)
mdl.get_topic_words(topic_id=0, top_n=50)

# Number of words allocated to each topic (num)
mdl.get_count_by_topics()

# hLDA Words distribution for each of the live topics (only probabilities)
words_topics_distr = list(map(lambda x: hlda.get_topic_word_dist(x) if hlda.is_live_topic(x) else [], range(hlda.k)))
'''

print('')

# %% [markdown]
# ## Setting hyperparameters

# %%
seed = 12345

#num_topics = list(np.arange(5, 30, 5)) + list(np.arange(30, 110, 10))
#eta_hlda = = [0.0001, 0.001, 0.01, 0.2,  0.3, 0.5, 0.7, 1]

eta_hlda = 0.2
num_topics = 40
alpha = 0.001 # https://ethen8181.github.io/machine-learning/clustering/topic_model/LDA.html
eta = 0.00001 # https://ethen8181.github.io/machine-learning/clustering/topic_model/LDA.html
gamma = 0.001

# %% [markdown]
# ## Latent Dirichlet Allocation (LDAModel)

# %%
# %%time

lda = to.LDAModel(k=num_topics, alpha=alpha, eta=eta, seed=seed)
list(map(lda.add_doc, words_in_docs))
lda.train(workers=1, iter = 100)
print(lda.summary(topic_word_top_n = 30), end='\n\n')

ch = coherence.Coherence(lda, top_n = 50)
print('-----------------------------------------------')
print('Coherence score =', ch.get_score(), end='\n\n')
# Out:
# <Basic Info>
# | LDAModel (current version: 0.12.7)
# | 15342 docs, 2850809 words
# | Total Vocabs: 63240, Used Vocabs: 63240
# | Entropy of words: 8.23205
# | Entropy of term-weighted words: 8.23205
# | Removed Vocabs: <NA>
# |
# <Training Info>
# | Iterations: 100, Burn-in steps: 0
# | Optimization Interval: 10
# | Log-likelihood per word: -8.85266
# |
# <Initial Parameters>
# | tw: TermWeight.ONE
# | min_cf: 0 (minimum collection frequency of words)
# | min_df: 0 (minimum document frequency of words)
# | rm_top: 0 (the number of top words to be removed)
# | k: 40 (the number of topics between 1 ~ 32767)
# | alpha: [0.001] (hyperparameter of Dirichlet distribution for document-topic, given as a single `float` in case of symmetric prior and as a list with length `k` of `float` in case of asymmetric prior.)
# | eta: 1e-05 (hyperparameter of Dirichlet distribution for topic-word)
# | seed: 12345 (random seed)
# | trained in version 0.12.7
# |
# <Parameters>
# | alpha (Dirichlet prior on the per-document topic distributions)
# |  [0.21325701 0.21935132 0.19311926 0.4152776  0.22780499 0.1943634
# |   0.18032275 0.23432255 0.24637868 0.13180022 0.12330434 0.38501355
# |   0.08089353 0.27251264 0.19417758 0.05402305 0.1211279  0.12882832
# |   0.16019638 0.24058093 0.18449742 0.18109798 0.306157   0.16122879
# |   0.17689867 0.20321633 0.26816818 0.1663912  0.24283513 0.16070087
# |   0.29192308 0.1378159  0.41247255 0.2667883  0.08555707 0.27127096
# |   0.13610369 0.2299616  0.17146277 0.11458912]
# | eta (Dirichlet prior on the per-topic word distribution)
# |  1e-05
# |
# <Topics>
# | #0 (90253) : сексуальный насилие год случай оон жертва организация сторона преступление военный заявить представитель армия число сообщать доклад церковь священник сша расследование время южный страна человек япония власть республика жалоба сила сообщить
# | #1 (53131) : дело статья новый здание дмитриев фото сотрудник год полицейский александр день стать часть наказание процесс выйти однако уголовный екатеринбург первый нарушение андрей отправить итог служба режим работа срок сергей административный
# | #2 (63762) : женщина страна человек полиция германия власть мигрант город беженец группа немецкий министр европа протест индия против партия местный кёльн тысяча новый сми год парламент заявить массовый стать турция нападение глава
# | #3 (129585) : мужчина изнасиловать женщина дом житель квартира знакомый произойти местный полиция изнасилование злоумышленник избить сообщать девушка насильник затем надругаться ранее жительница жертва двое молодой район пьяный время задержать гость пострадать попытаться
# | #4 (103636) : женщина насилие право страна отношение закон домашний защита жертва россия принять мужчина центр помощь борьба организация проблема семья работа мир против сексуальный общественный социальный решение проект гендерный физический женский международный
# | #5 (74068) : сша трамп домогательство сексуальный женщина заявить слово президент обвинить пост против опубликовать обвинение байден metoo дональд бывший газета время сказать назвать кандидат поведение американский движение партия скандал модель насилие отметить
# | #6 (52844) : информация ребёнок мочь запретить некоторый закон настоящий федеральный развитие здоровье материал норма основание ирина час распространение защита отношение ограничение источник вред информационный екатеринбург содержать раздел тема возрастной сеть фалькин мелкий
# | #38 (47981) : сестра отец девушка насилие хачатурян год дочь михаил дело убийство сторона мария брат отношение слово убить время действие девочка рассказать адвокат старший младший насиловать июль сексуальный собственный заявить признать экспертиза
# | #39 (61481) : изнасилование полицейский мвд отдел начальник полиция район уфа коллега уфимский сотрудник дело подозревать уволить трое башкирия россия бывший вопрос октябрь омвд орган девушка ночь матвеев групповой дознавательница галиев яромчук миграция
# |
#
# None
#
# -----------------------------------------------
# Coherence score = -2.1779757385093896
#
# CPU times: total: 1min 9s
# Wall time: 1min 13s

# %% [markdown]
# ## Hierarchical LDA (HLDAModel)

# %%
# %%time

hlda = to.HLDAModel(depth=3, alpha=alpha, eta=eta_hlda, gamma=gamma, seed=seed)
list(map(hlda.add_doc, words_in_docs))
hlda.train(workers=1, iter = 100)
hlda.summary(topic_word_top_n = 30)

ch = coherence.Coherence(hlda, top_n = 50)
print('-----------------------------------------------')
print('Coherence score =', ch.get_score(), end='\n\n')
# Out:
# <Basic Info>
# | HLDAModel (current version: 0.12.7)
# | 15342 docs, 2850809 words
# | Total Vocabs: 63240, Used Vocabs: 63240
# | Entropy of words: 8.23205
# | Entropy of term-weighted words: 8.23205
# | Removed Vocabs: <NA>
# |
# <Training Info>
# | Iterations: 100, Burn-in steps: 0
# | Optimization Interval: 10
# | Log-likelihood per word: -8.32406
# |
# <Initial Parameters>
# | tw: TermWeight.ONE
# | min_cf: 0 (minimum collection frequency of words)
# | min_df: 0 (minimum document frequency of words)
# | rm_top: 0 (the number of top words to be removed)
# | depth: 3 (the maximum depth level of hierarchy between 2 ~ 32767)
# | alpha: [0.001] (hyperparameter of Dirichlet distribution for document-depth level, given as a single `float` in case of symmetric prior and as a list with length `depth` of `float` in case of asymmetric prior.)
# | eta: 0.2 (hyperparameter of Dirichlet distribution for topic-word)
# | gamma: 0.001 (concentration coeficient of Dirichlet Process)
# | seed: 12345 (random seed)
# | trained in version 0.12.7
# |
# <Parameters>
# | alpha (Dirichlet prior on the per-document depth level distributions)
# |  [0.12526135 0.21915685 0.11595927]
# | eta (Dirichlet prior on the per-topic word distribution)
# |  0.2
# | gamma (concentration coefficient of Dirichlet Process)
# |  0.001
# | Number of Topics: 12
# |
# <Topics>
# | #0 (981494, 15342) : женщина год насилие человек мочь сексуальный стать ребёнок говорить жертва время мужчина случай рассказать слово страна жизнь история сказать день первый большой россия работа право проблема семья заявить отношение девушка
# |   #8 (1126227, 15329) : год изнасилование мужчина дело женщина изнасиловать суд преступление убийство задержать девушка уголовный сексуальный действие подозревать область полиция характер насильственный сообщить отношение рф следствие следственный новость район сообщать обвинять дом совершить
# |     #16 (734144, 15214) : год сексуальный насилие обвинение домогательство женщина изнасилование обвинить суд сша заявить дело сообщать связь актёр вайнштейн отношение бывший американский сторона время против слово ранее массовый расследование жертва актриса коммуникация стать
# |     #19 (1988, 44) : унтервегер премия шнобелевский лауреат гульназа область improbable research проститутка изобретение учёный парковка лазерный венский таня душитель кадило youtube кпрф тонкий люба коляска борода прохожий полноэкранный биология минеев носорог режим развернуть
# |     #20 (1843, 50) : фото чикатить пичушкина reuters обстрел скопин мур купить молоток кравченко разрушить алла грибинюк костоев оперативник головкин всу коммерсантъ батынский набиев полка мастурбация фишер вэсэушник доска бригада киев ростовский донецк alexander
# |     #22 (696, 21) : мик ряховский пермский мемориал микова краевой учебник ранетка омбудсмен владимирович ноздровский гомосексуализм пермь зaявить цапковы фантастический джина аспирантура pegida майданюк огурцов кущёвский першакова цго трамп женя сексуaльный увековечивание влияние библиотекарь
# |   #9 (1892, 8) : м ф б паук самка далее самец паутина птицеед каракурт яд бывать линька половой ядовитый насекомое вообще нора волосок смертельный съедать чёрный размер очень вид обычно жить охотиться сперма полова
# |     #17 (1085, 8) : i and my the to was for it me that аарон a брат in ник гарнизон on картер сша олимпийский be обвинение by гавайский нба with блин this but you
# |   #10 (447, 4) : якобсон миниатюра хореограф балет нимфа emblem ниося степанов танец минотавр fire танцовщик тальонить вечный three оживать музыка скульптура роден труппа хореографический houses денис балерина скульптор мастер еркин балетмейстер леонид актёр
# |     #18 (448, 4) : украина вторжение путин титан la дюкурно ucraina putin алексий сто прокат di жюлий каннский in per парадоксальный ветвь пальмовый нато russia учение спица западноевропейский успевать смысл кадиллак бертран демонстративно минский
# |   #11 (545, 1) : премия нобелевский область физика риа литература wikimedia commons org теория domain физиология public алексеевич поэзия традиция жидкий сергеевич леонидович лев николай александрович черенковый globallookpress com открытие михаилович www вручить юрий
# |     #21 (0, 1) : год женщина сексуальный изнасилование насилие дело мужчина суд девушка преступление изнасиловать человек отношение обвинение жертва действие стать время убийство полиция задержать мочь уголовный новость сообщать сообщить характер ранее заявить рассказать
# |
#
# -----------------------------------------------
# Coherence score = -4.5705310998944
#
# CPU times: total: 37.8 s
# Wall time: 38.1 s

# %% [markdown]
# ## Pachinko Allocation (PAModel)

# %%
# %%time

pa = to.PAModel(k1=3, k2=num_topics, alpha=alpha, subalpha=alpha, eta=eta, seed=seed)
list(map(pa.add_doc, words_in_docs))
pa.train(workers=1, iter = 100)
pa.summary(topic_word_top_n = 30)

ch = coherence.Coherence(pa, top_n = 50)
print('-----------------------------------------------')
print('Coherence score =', ch.get_score(), end='\n\n')
# Out:
# <Basic Info>
# | PAModel (current version: 0.12.7)
# | 15342 docs, 2850809 words
# | Total Vocabs: 63240, Used Vocabs: 63240
# | Entropy of words: 8.23205
# | Entropy of term-weighted words: 8.23205
# | Removed Vocabs: <NA>
# |
# <Training Info>
# | Iterations: 100, Burn-in steps: 0
# | Optimization Interval: 1
# | Log-likelihood per word: -10.20365
# |
# <Initial Parameters>
# | tw: TermWeight.ONE
# | min_cf: 0 (minimum collection frequency of words)
# | min_df: 0 (minimum document frequency of words)
# | rm_top: 0 (the number of top words to be removed)
# | k1: 3 (the number of super topics between 1 ~ 32767)
# | k2: 40 (the number of sub topics between 1 ~ 32767)
# | alpha: [0.001] (initial hyperparameter of Dirichlet distribution for document-super topic, given as a single `float` in case of symmetric prior and as a list with length `k1` of `float` in case of asymmetric prior.)
# | subalpha: [0.001] (initial hyperparameter of Dirichlet distribution for super-sub topic, given as a single `float` in case of symmetric prior and as a list with length `k2` of `float` in case of asymmetric prior.)
# | eta: 1e-05 (hyperparameter of Dirichlet distribution for sub topic-word)
# | seed: 12345 (random seed)
# | trained in version 0.12.7
# |
# <Parameters>
# | alpha (Dirichlet prior on the per-document super topic distributions)
# |  [0.001 0.001 0.001]
# | subalpha (Dirichlet prior on the sub topic distributions for each super topic)
# |  Super #0: [0.13212502 0.15166907 0.14486344 0.2052242  0.14860071 0.10213185
# |    0.1034636  0.31940112 0.2601174  0.1383749  0.30080345 0.11683
# |    0.1143432  0.23838614 0.10201556 0.11901777 0.343447   0.09598031
# |    0.22861063 0.24904093 0.21208784 0.12211636 0.14604472 0.16591147
# |    0.3125969  0.09025434 0.17141967 0.08510088 0.12568521 0.21684648
# |    0.20647839 0.14416441 0.22019285 0.15012318 0.18771565 0.23124585
# |    0.11985631 0.21191916 0.2998173  0.1469717 ]
# |  Super #1: [0.14339295 0.17128989 0.1515181  0.2026981  0.14045052 0.11243732
# |    0.09716786 0.33757517 0.251861   0.14522895 0.3326555  0.11424305
# |    0.12595646 0.2547443  0.09512943 0.1307035  0.37994704 0.09176181
# |    0.2077824  0.25937933 0.2194932  0.1141277  0.15644978 0.15868361
# |    0.35100567 0.09069318 0.18144712 0.08713213 0.11404305 0.25234964
# |    0.1935301  0.15623242 0.21455744 0.14721392 0.20062092 0.23977071
# |    0.12901893 0.2004134  0.30693322 0.1497    ]
# |  Super #2: [0.13585016 0.15893984 0.14913806 0.20230044 0.14324386 0.0981676
# |    0.10320861 0.32318643 0.26257607 0.14393908 0.2949779  0.11118675
# |    0.11594266 0.22535054 0.10447503 0.12617624 0.36331648 0.09120581
# |    0.22223802 0.25564128 0.20924203 0.11962071 0.1497676  0.14824799
# |    0.33249438 0.08261909 0.16209109 0.09101357 0.12583604 0.22199513
# |    0.19802691 0.14265305 0.21904588 0.15314172 0.17782436 0.24144292
# |    0.12971616 0.20988236 0.3001072  0.14801328]
# | eta (Dirichlet prior on the per-subtopic word distribution)
# |  1e-05
# |
# <Topics>
# | Sub-topic distribution of Super-topics
# |  #Super0 (943929) : #7 #13 #16 #38 #10 #29 #19 #37 #24 #32 #2 #35 #8 #3 #18 #27 #30 #20 #28 #5 #39 #34 #23 #21 #11 #26 #9 #25 #33 #22
# |  #Super1 (960509) : #7 #16 #13 #10 #38 #29 #24 #19 #35 #2 #37 #8 #32 #3 #18 #20 #27 #30 #5 #28 #39 #34 #23 #9 #25 #11 #26 #31 #33 #22
# |  #Super2 (946371) : #7 #16 #13 #38 #10 #19 #29 #37 #24 #35 #2 #8 #32 #27 #18 #3 #20 #28 #30 #39 #5 #34 #9 #11 #23 #33 #21 #25 #31 #22
# | Word distribution of Sub-topics
# |  #0 (36854) : машина водитель такси таксист автомобиль час район опечатка получить дело ребёнок видео кадр дорога город место мальчик салон работать детский вернуть сделать отвезти обратиться дмитрий фото услуга неизвестный ехать красноярск
# |  #1 (39734) : женщина человек тысяча рубль похищение деньга старший молодой помощник похитить руководитель москва иванов насиловать дом март затем средний юлия арестовать гостиница пенсионер северный столичный сбежать этаж потребовать провести школьник рязанский
# |  #2 (94577) : сексуальный актёр домогательство обвинение год вайнштейн актриса женщина обвинить продюсер режиссёр спейся харви насилие изнасилование фильм заявить депардье the против американский пациентка голливудский отношение скандал французский присяжный звезда сообщать предъявить
# |  #34 (57593) : время место работать работа день помочь найти смочь оказаться рука нижний рассказывать сидеть начало анастасия взять наталья дом деньга палец месяц помощь прийтись стать общий пара некоторый заниматься открыть начаться
# |  #35 (95046) : рассказать год сказать слово девушка стать история время знать хотеть друг написать говорить момент признаться сделать случиться рассказывать подруга детство никто первый день решить очень несколько спустя подробность просто начать
# |  #36 (36266) : врач заключить больница находиться осудить м состояние саратовский сотрудник колония тюрьма б камера учреждение пациент видео фсин наркотик получить сизый операция человек попасть тюремный медицинский бывший исправительный отбывать мочь беспомощный
# |  #37 (101827) : женщина страна насилие право сексуальный отношение власть германия принять случай против борьба человек мужчина беженец правительство министр место организация международный мир женский исследование защита гендерный государство проблема немецкий новый европа
# |  #38 (117150) : дело действие уголовный следственный сексуальный характер отношение насильственный возбудить комитет рф сообщить управление ск статья россия орган область преступление следователь изнасилование сотрудник ведомство факт совершение проверка ук мвд подозревать следствие
# |  #39 (63682) : сексуальный год насилие оон военный случай организация армия число преступление жертва сша сторона время южный доклад вооружённый военнослужащий представитель война человек япония сила республика страна солдат корея фонд японский тыс
# |
#
# -----------------------------------------------
# Coherence score = -2.8709245852078484
#
# CPU times: total: 4min 8s
# Wall time: 4min 9s

# %% [markdown]
# ## Hierarchical PA (HPAModel)

# %%
# %%time

hpa = to.HPAModel(k1=3, k2=num_topics, alpha=alpha, subalpha=alpha, eta=eta, seed=seed)
list(map(hpa.add_doc, words_in_docs))
hpa.train(workers=1, iter = 100)
hpa.summary(topic_word_top_n = 30)

ch = coherence.Coherence(hpa, top_n = 50)
print('-----------------------------------------------')
print('Coherence score =', ch.get_score(), end='\n\n')
# Out:
# <Basic Info>
# | HPAModel (current version: 0.12.7)
# | 15342 docs, 2850809 words
# | Total Vocabs: 63240, Used Vocabs: 63240
# | Entropy of words: 8.23205
# | Entropy of term-weighted words: 8.23205
# | Removed Vocabs: <NA>
# |
# <Training Info>
# | Iterations: 100, Burn-in steps: 0
# | Optimization Interval: 1
# | Log-likelihood per word: -9.88751
# |
# <Initial Parameters>
# | tw: TermWeight.ONE
# | min_cf: 0 (minimum collection frequency of words)
# | min_df: 0 (minimum document frequency of words)
# | rm_top: 0 (the number of top words to be removed)
# | k1: 3 (the number of super topics between 1 ~ 32767)
# | k2: 40 (the number of sub topics between 1 ~ 32767)
# | alpha: [0.001] (initial hyperparameter of Dirichlet distribution for document-topic, given as a single `float` in case of symmetric prior and as a list with length `k1 + 1` of `float` in case of asymmetric prior.)
# | subalpha: [0.001] (initial hyperparameter of Dirichlet distribution for super-sub topic, given as a single `float` in case of symmetric prior and as a list with length `k2 + 1` of `float` in case of asymmetric prior.)
# | eta: 1e-05 (hyperparameter of Dirichlet distribution for topic-word)
# | seed: 12345 (random seed)
# | trained in version 0.12.7
# |
# <Parameters>
# | alpha (Dirichlet prior on the per-document super topic distributions)
# |  [1.0732403] [1.2011116 1.1030017 1.0653065]
# | subalpha (Dirichlet prior on the sub topic distributions for each super topic)
# |  Super #0: [0.5660946] [0.04004495 0.01662218 0.0311059  0.02172137 0.02714419 0.02021956
# |    0.01341613 0.02289976 0.01421073 0.02221081 0.04804108 0.01926153
# |  #31 (83894) : обвинение сексуальный год насилие изнасилование обвинить предъявить сообщать заявление полиция заявить подать против расследование иск газета женщина ранее адвокат утверждать преступление инцидент суд сообщить обвинять отношение дело предполагать выдвинуть арестовать
# |  #32 (35599) : новость фонтанка бизнес петербург петербургский издание последний политика роскомнадзор сетевой наш город видео день государственный россия орган интернет десятка найти происходить работа рассказать общество дать тысяча власть искусство читать чиновник
# |  #33 (18016) : нижегородский м священник католический папа конвенция турция самый римский б ф миротворец польша регион опасный епископ проект марш воз посольство государство ответственность комиссия здоровье участие начаться нижегородец конго запись иностранный
# |  #34 (171954) : действие дело уголовный характер рф насильственный сексуальный следственный отношение область изнасилование преступление задержать подозревать ск ук возбудить статья ст управление совершить следствие комитет совершение ч сообщить россия житель скр потерпевший
# |  #35 (49167) : год эл фс известие сайт право ооо миц коммуникация портал информационный надзор связь федеральный июль массовый технология сфера служба материал защитить декабрь зарегистрировать федерация свидетельство iz регистрация функционировать рф любой
# |  #36 (23852) : иа врач сообщать регнум сексуальный пациентка regnum эпштейн январь действие изнасилование находиться отношение насилие сообщить дмитриев проверка джеффри заявление орган июль дело ложный подозрение несовершеннолетний беспомощный правоохранительный ранее декабрь обвинить
# |  #37 (23415) : партия заявить пост the опубликовать аборт президент скандал политический выборы глава ноябрь сми газета верховный издание социальный писательница соцсеть шуай пэн сеть чемпионка слово обвинение ситуация политика журналист член адрес
# |  #38 (12715) : испания роналда рубиалеса изнасилование бразилия обвинить заявление чемпион заявить майорг женщина криштиану поцелуй мочь художник подать обновить издание поцеловать история адвокат слово футболист стать ювентус имя американка карелия диджитал шкулёва
# |  #39 (17261) : екатеринбург свердловский алексей павленский собчак анастасия запретить афганистан проверка информация ирина федеральный заявление защита май норма ремонт иван валерий апрель фестиваль сообщить рассказать вос отношение пётр журналист вуд тема апелляционный
# |
#
# -----------------------------------------------
# Coherence score = -1.5920919168807321
#
# CPU times: total: 8min 21s
# Wall time: 8min 34s

# %% [markdown]
# ## Correlated Topic Model (CTModel)

# %%
# %%time

ctm = to.CTModel(k=num_topics, smoothing_alpha=alpha, eta=eta, seed=seed)
list(map(ctm.add_doc, words_in_docs))
ctm.train(workers=1, iter = 100)
ctm.summary(topic_word_top_n = 30)

ch = coherence.Coherence(pa, top_n = 50)
print('-----------------------------------------------')
print('Coherence score =', ch.get_score(), end='\n\n')
# Out:
# <Basic Info>
# | CTModel (current version: 0.12.7)
# | 15342 docs, 2850809 words
# | Total Vocabs: 63240, Used Vocabs: 63240
# | Entropy of words: 8.23205
# | Entropy of term-weighted words: 8.23205
# | Removed Vocabs: <NA>
# |
# <Training Info>
# | Iterations: 100, Burn-in steps: 0
# | Optimization Interval: 2
# | Log-likelihood per word: -7.00474
# |
# <Initial Parameters>
# | tw: TermWeight.ONE
# | min_cf: 0 (minimum collection frequency of words)
# | min_df: 0 (minimum document frequency of words)
# | rm_top: 0 (the number of top words to be removed)
# | k: 40 (the number of topics between 1 ~ 32767)
# | smoothing_alpha: [0.001] (small smoothing value for preventing topic counts to be zero, given as a single `float` in case of symmetric and as a list with length `k` of `float` in case of asymmetric.)
# | eta: 1e-05 (hyperparameter of Dirichlet distribution for topic-word)
# | seed: 12345 (random seed)
# | trained in version 0.12.7
# |
# <Parameters>
# | prior_mean (Prior mean of Logit-normal for the per-document topic distributions)
# |  [-4.846388   -5.133446   -5.2446284  -5.3043814  -5.584006   -6.112633
# |   -5.854771   -6.198837   -6.2920732  -6.4010243  -6.247838   -6.1582317
# |   -6.106627   -6.2138915  -6.4182014  -6.481364   -6.4748507  -6.256916
# |   -6.429595   -5.974224   -6.375793   -6.4808793  -6.3722963  -6.287881
# |   -6.257124   -5.920422   -6.1736856  -4.959349   -5.5486884  -4.819806
# |   -5.0424285  -5.2617054  -4.057224   -4.157595   -4.5571456  -3.4449127
# |   -0.79990786 -0.03576128 -0.24777497  0.09977327]
# | prior_cov (Prior covariance of Logit-normal for the per-document topic distributions)
# |  [[ 2.0977232e+01  4.7883677e+00  3.5354640e+00 ...  9.3495816e-02
# |     9.3938851e-01  5.4329697e-02]
# |   [ 4.7883677e+00  2.0551094e+01  3.5980916e+00 ...  1.7928499e-01
# |     8.8737917e-01 -4.5507740e-02]
# |   [ 3.5354640e+00  3.5980916e+00  2.0482197e+01 ...  2.6377331e-02
# |     5.4241228e-01 -5.1884845e-02]
# |   ...
# |   [ 9.3495816e-02  1.7928499e-01  2.6377331e-02 ...  1.3308296e-01
# |     2.9967261e-02  2.7480554e-03]
# |   [ 9.3938851e-01  8.8737917e-01  5.4241228e-01 ...  2.9967261e-02
# |     5.5709267e-01  1.5714383e-02]
# |   [ 5.4329697e-02 -4.5507740e-02 -5.1884845e-02 ...  2.7480554e-03
# |     1.5714383e-02  1.6256306e-02]]
# | eta (Dirichlet prior on the per-topic word distribution)
# |  1e-05
# |
# <Topics>
# | #0 (89460) : задержать подозревать мужчина область полиция район орган дом москва уголовный полицейский возбудить следственный нападение напасть улица изнасиловать следователь преступление правоохранительный следствие злоумышленник ск сотрудник насильник изнасилование совершить преступник мигрант местный
# | #1 (85937) : уголовный дело действие рф следственный характер насильственный ук преступление следствие ст подозревать область ск ч район совершение россия возбудить управление статья убийство совершить задержать следователь потерпевший комитет скр установить совершенный
# | #2 (75124) : девушка мужчина дом женщина изнасиловать убийство квартира полиция убить место затем молодой подруга человек улица время преступник потерпевший студентка стать удаться жертва знакомый насильник произойти момент нож помощь автомобиль машина
# | #3 (75052) : год изнасилование преступление суд дело девушка полиция жертва отношение потерпевший находиться район октябрь насильник срок обвинять состояние следствие пожизненный свобода расследование ноябрь несколько момент заключение август преступник сообщить маньяк совершить
# | #4 (67140) : женщина полиция место дело получить дом произойти республика человек полицейский стать муж сотрудник результат город время район оказаться ночь россия нападение внутренний орган факт данные трое пострадать часть местный бывший
# | #5 (56079) : год связь массовый развитие информация российский коммуникация июль поддержка финансовый министерство дать информационный декабрь портал цифровой материал право рф данный сайт авторский рекомендация федеральный оферта содержимое служба фотография партнёр ооо
# | #6 (63579) : маньяк девушка убийство мужчина жертва место тело год рассказать преступник человек выйти парень первый александр несколько стать насиловать сизый город телефон час удаться обнаружить смочь часть ребёнок нож спустя время
# | #7 (56040) : правда слово история семья говорить мочь сказать несколько рассказать сделать запретить имя хотеть сын старый контакт писать почему жена появиться друг евгений ребёнок секс хотя очень далее яркий назад отказаться
